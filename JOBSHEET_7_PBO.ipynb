# %% [markdown]
# <a href="https://colab.research.google.com/github/acti12/2026_PemrogamanBerbasisObjek/blob/main/JOBSHEET_7_PBO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Praktikum 1 - try...except Dasar dalam Metode Kelas

# %%
class DataStore:
    def __init__(self, nama_store="Default Store"):
        # Dictionary internal untuk menyimpan data (anggap sebagai 'protected')
        self._data = {}
        self.nama = nama_store
        print(f"DataStore '{self.nama}' dibuat.")

    def tambah_data(self, key, value):
        """Menambahkan data ke dalam store."""
        print(f"[{self.nama}] Menambahkan data: '{key}' -> {value}")
        self._data[key] = value
        print("  -> Data berhasil ditambahkan.")

    def get_data(self, key):
        """
        Mencoba mendapatkan data berdasarkan key.
        Menangani KeyError jika key tidak ada.
        """
        print(f"[{self.nama}] Mencoba mengambil data dengan key: '{key}'")
        try:
            # Baris ini berpotensi menimbulkan KeyError
            nilai = self._data[key]
            print(f"  -> Data ditemukan: {nilai}")
            return nilai
        except KeyError:
            # Blok ini dijalankan jika KeyError terjadi di blok try
            print(f"  -> ERROR: Key '{key}' tidak ditemukan di DataStore '{self.nama}'.")
            # Mengembalikan None atau nilai default lain sebagai indikasi gagal
            return None


# --- Kode Utama ---
if __name__ == "__main__":
    # Membuat instance DataStore
    store_produk = DataStore("Toko Produk")

    # Menambahkan beberapa data
    store_produk.tambah_data("Buku Tulis", 15000)
    store_produk.tambah_data("Pensil 2B", 2000)

    # Mengambil data yang ada (seharusnya berhasil)
    print("\nMengambil data yang ADA:")
    harga_buku = store_produk.get_data("Buku Tulis")
    if harga_buku is not None:
        print(f"  Harga Buku Tulis adalah: {harga_buku}")

    # Mengambil data yang TIDAK ada (seharusnya memicu except)
    print("\nMengambil data yang TIDAK ADA:")
    harga_penggaris = store_produk.get_data("Penggaris")
    if harga_penggaris is None:
        print("  Harga Penggaris tidak ditemukan (sesuai ekspektasi).")
# Out:
# DataStore 'Toko Produk' dibuat.
# [Toko Produk] Menambahkan data: 'Buku Tulis' -> 15000
#   -> Data berhasil ditambahkan.
# [Toko Produk] Menambahkan data: 'Pensil 2B' -> 2000
#   -> Data berhasil ditambahkan.
#
# Mengambil data yang ADA:
# [Toko Produk] Mencoba mengambil data dengan key: 'Buku Tulis'
#   -> Data ditemukan: 15000
#   Harga Buku Tulis adalah: 15000
#
# Mengambil data yang TIDAK ADA:
# [Toko Produk] Mencoba mengambil data dengan key: 'Penggaris'
#   -> ERROR: Key 'Penggaris' tidak ditemukan di DataStore 'Toko Produk'.
#   Harga Penggaris tidak ditemukan (sesuai ekspektasi).

# %% [markdown]
# # Praktikum 2 - Menangani Beberapa Exception Spesifik

# %%
class KalkulatorAngka:
    def __init__(self):
        print("Kalkulator Angka siap.")

    def bagi(self, angka1, angka2):
        """
        Membagi angka1 dengan angka2.
        Menangani potensi ValueError (jika input bukan angka)
        dan ZeroDivisionError (jika pembagi nol) secara terpisah.
        """
        print(f"\nMencoba membagi '{angka1}' dengan '{angka2}'...")
        try:
            # Konversi input ke float, bisa memicu ValueError
            num1 = float(angka1)
            num2 = float(angka2)

            # Operasi pembagian, bisa memicu ZeroDivisionError
            hasil = num1 / num2

            print(f"  -> Hasil pembagian: {hasil}")
            return hasil

        # Menangkap ValueError secara spesifik
        except ValueError:
            print("  -> ERROR: Input tidak valid! Pastikan kedua input adalah angka.")
            return None

        # Menangkap ZeroDivisionError secara spesifik
        except ZeroDivisionError:
            print("  -> ERROR: Tidak bisa melakukan pembagian dengan nol.")
            return None

        # Menangkap exception lain yang mungkin tidak terduga (opsional)
        except Exception as e:
            print(f"  -> ERROR Lainnya: Terjadi kesalahan - {e}")
            return None


# --- Kode Utama ---
if __name__ == "__main__":
    calc = KalkulatorAngka()

    print("--- Tes Kalkulator ---")
    hasil1 = calc.bagi(100, 5)      # Operasi sukses
    hasil2 = calc.bagi(20, 0)       # Memicu ZeroDivisionError
    hasil3 = calc.bagi("limapuluh", 10) # Memicu ValueError saat konversi num1
    hasil4 = calc.bagi(50, "sepuluh") # Memicu ValueError saat konversi num2

    print("\n--- Ringkasan Hasil ---")
    print(f"Hasil 1 (100/5): {hasil1}")
    print(f"Hasil 2 (20/0): {hasil2}")
    print(f"Hasil 3 ('limapuluh'/10): {hasil3}")
    print(f"Hasil 4 (50/'sepuluh'): {hasil4}")
# Out:
# Kalkulator Angka siap.
# --- Tes Kalkulator ---
#
# Mencoba membagi '100' dengan '5'...
#   -> Hasil pembagian: 20.0
#
# Mencoba membagi '20' dengan '0'...
#   -> ERROR: Tidak bisa melakukan pembagian dengan nol.
#
# Mencoba membagi 'limapuluh' dengan '10'...
#   -> ERROR: Input tidak valid! Pastikan kedua input adalah angka.
#
# Mencoba membagi '50' dengan 'sepuluh'...
#   -> ERROR: Input tidak valid! Pastikan kedua input adalah angka.
#
# --- Ringkasan Hasil ---
# Hasil 1 (100/5): 20.0
# Hasil 2 (20/0): None
# Hasil 3 ('limapuluh'/10): None
# Hasil 4 (50/'sepuluh'): None

# %% [markdown]
# # Praktikum 3 - Menggunakan else dan finally dalam Metode

# %%
import os  # Diperlukan untuk menghapus file dummy nanti

class FileProcessor:
    def __init__(self, nama_file):
        self.nama_file = nama_file
        self._file_handle = None  # Untuk menyimpan objek file saat dibuka
        print(f"\n-> FileProcessor dibuat untuk file: '{self.nama_file}'")

    def baca_dan_proses(self):
        """Membuka, membaca, dan 'memproses' file, dengan cleanup di finally."""
        print(f"[{self.nama_file}] Mencoba memproses...")
        try:
            # 1. Mencoba membuka file untuk dibaca
            print(f"  [{self.nama_file}] Membuka file...")
            self._file_handle = open(self.nama_file, 'r', encoding='utf-8')  # Mode 'r' untuk baca

            # 2. Jika buka berhasil, coba baca isinya
            print(f"  [{self.nama_file}] Membaca isi file...")
            isi = self._file_handle.read()
            print(f"  -> File berhasil dibaca.")

            # 3. Simulasi pemrosesan isi
            print(f"  [{self.nama_file}] Memproses isi...")
            panjang_isi = len(isi)
            print(f"  -> Panjang isi: {panjang_isi} karakter.")
            # Simulasi: Anggap pemrosesan selalu berhasil jika baca berhasil

        except FileNotFoundError:
            # 4a. Blok ini jalan jika open() gagal karena file tidak ada
            print(f"  -> ERROR: File '{self.nama_file}' tidak ditemukan.")
        except UnicodeDecodeError:
            # 4b. Contoh error lain saat membaca file non-teks
            print(f"  -> ERROR: Gagal membaca '{self.nama_file}' sebagai teks (mungkin file biner?).")
        except Exception as e:
            # 4c. Menangkap error tak terduga lainnya saat try
            print(f"  -> ERROR Lainnya saat memproses file: {type(e).__name__} - {e}")
        else:
            # 5. Blok ini jalan HANYA JIKA try selesai tanpa exception
            print(f"  -> PEMROSESAN BERHASIL: Tidak ada error terjadi pada '{self.nama_file}'.")
        finally:
            # 6. Blok ini SELALU jalan setelah try/except/else selesai
            print(f"  [{self.nama_file}] Blok Finally: Melakukan cleanup...")
            if self._file_handle and not self._file_handle.closed:
                print(f"    Menutup file '{self.nama_file}'...")
                self._file_handle.close()
                print("    -> File berhasil ditutup.")
            else:
                # Ini akan terjadi jika file gagal dibuka (FileNotFoundError)
                # atau jika sudah ditutup karena error lain di try
                print("    -> File tidak perlu ditutup (belum dibuka atau sudah ditutup).")
        print(f"[{self.nama_file}] Selesai mencoba proses.")
        print("-" * 30)


# --- Kode Utama ---
if __name__ == "__main__":
    NAMA_FILE_SUKSES = "data_penting.txt"
    NAMA_FILE_GAGAL = "file_yang_tidak_ada.log"

    # Membuat file dummy untuk skenario sukses
    try:
        with open(NAMA_FILE_SUKSES, "w", encoding='utf-8') as f:
            f.write("Ini adalah baris pertama.\n")
            f.write("Baris kedua berisi data penting.\n")
        print(f"File dummy '{NAMA_FILE_SUKSES}' berhasil dibuat.")
    except IOError as e:
        print(f"Gagal membuat file dummy '{NAMA_FILE_SUKSES}': {e}")

    # Skenario 1: File ada dan proses berhasil
    print("\n--- Skenario 1: Proses Sukses ---")
    processor1 = FileProcessor(NAMA_FILE_SUKSES)
    processor1.baca_dan_proses()

    # Skenario 2: File tidak ada
    print("\n--- Skenario 2: File Tidak Ditemukan ---")
    processor2 = FileProcessor(NAMA_FILE_GAGAL)
    processor2.baca_dan_proses()

    # Cleanup file dummy
    try:
        if os.path.exists(NAMA_FILE_SUKSES):
            os.remove(NAMA_FILE_SUKSES)
            print(f"\nFile dummy '{NAMA_FILE_SUKSES}' dihapus.")
    except OSError as e:
        print(f"\nGagal menghapus file dummy '{NAMA_FILE_SUKSES}': {e}")
# Out:
# File dummy 'data_penting.txt' berhasil dibuat.
#
# --- Skenario 1: Proses Sukses ---
#
# -> FileProcessor dibuat untuk file: 'data_penting.txt'
# [data_penting.txt] Mencoba memproses...
#   [data_penting.txt] Membuka file...
#   [data_penting.txt] Membaca isi file...
#   -> File berhasil dibaca.
#   [data_penting.txt] Memproses isi...
#   -> Panjang isi: 59 karakter.
#   -> PEMROSESAN BERHASIL: Tidak ada error terjadi pada 'data_penting.txt'.
#   [data_penting.txt] Blok Finally: Melakukan cleanup...
#     Menutup file 'data_penting.txt'...
#     -> File berhasil ditutup.
# [data_penting.txt] Selesai mencoba proses.
# ------------------------------
#
# --- Skenario 2: File Tidak Ditemukan ---
#
# -> FileProcessor dibuat untuk file: 'file_yang_tidak_ada.log'
# [file_yang_tidak_ada.log] Mencoba memproses...
#   [file_yang_tidak_ada.log] Membuka file...
#   -> ERROR: File 'file_yang_tidak_ada.log' tidak ditemukan.
#   [file_yang_tidak_ada.log] Blok Finally: Melakukan cleanup...
#     -> File tidak perlu ditutup (belum dibuka atau sudah ditutup).
# [file_yang_tidak_ada.log] Selesai mencoba proses.
# ------------------------------
#
# File dummy 'data_penting.txt' dihapus.

# %% [markdown]
# # Praktikum 04: Mengakses Objek Exception (as e)

# %%
class KalkulatorAngka:
    def __init__(self):
        print("Kalkulator Angka siap.")

    def bagi(self, angka1, angka2):
        """
        Membagi angka1 dengan angka2.
        Menangkap objek exception untuk menampilkan detail error.
        """
        print(f"\nMencoba membagi '{angka1}' dengan '{angka2}'...")
        try:
            num1 = float(angka1)
            num2 = float(angka2)
            if num2 == 0:
                # Melempar ZeroDivisionError secara eksplisit dengan pesan kustom
                raise ZeroDivisionError("Pembagi tidak boleh nol secara eksplisit.")

            hasil = num1 / num2
            print(f"  -> Hasil pembagian: {hasil}")
            return hasil

        # Menangkap ValueError dan menyimpannya di variabel 'e_val'
        except ValueError as e_val:
            print(f"  -> ERROR Konversi: Input tidak valid.")
            # Menampilkan representasi string dari objek exception e_val
            print(f"     Detail Error (ValueError): {e_val}")
            return None

        # Menangkap ZeroDivisionError dan menyimpannya di variabel 'e_zero'
        except ZeroDivisionError as e_zero:
            print(f"  -> ERROR Pembagian: Tidak dapat membagi dengan nol.")
            # Menampilkan representasi string dari objek exception e_zero
            print(f"     Detail Error (ZeroDivisionError): {e_zero}")
            return None

        # Menangkap exception lain dan menyimpannya di variabel 'e'
        except Exception as e:
            print(f"  -> ERROR Lainnya: Terjadi kesalahan tak terduga.")
            # Menampilkan representasi string dari objek exception e
            print(f"     Detail Error (Lainnya): {type(e).__name__} - {e}")
            return None


# --- Kode Utama ---
if __name__ == "__main__":
    calc = KalkulatorAngka()

    print("--- Tes Kalkulator ---")
    hasil1 = calc.bagi(100, 5)           # Sukses
    hasil2 = calc.bagi(20, 0)            # Memicu ZeroDivisionError
    hasil3 = calc.bagi("limapuluh", 10)  # Memicu ValueError
    hasil4 = calc.bagi(10, [])           # Memicu TypeError (ditangkap except Exception)

    print("\n--- Ringkasan Hasil ---")
    print(f"Hasil 1 (100/5): {hasil1}")
    print(f"Hasil 2 (20/0): {hasil2}")
    print(f"Hasil 3 ('limapuluh'/10): {hasil3}")
    print(f"Hasil 4 (10/[]): {hasil4}")
# Out:
# Kalkulator Angka siap.
# --- Tes Kalkulator ---
#
# Mencoba membagi '100' dengan '5'...
#   -> Hasil pembagian: 20.0
#
# Mencoba membagi '20' dengan '0'...
#   -> ERROR Pembagian: Tidak dapat membagi dengan nol.
#      Detail Error (ZeroDivisionError): Pembagi tidak boleh nol secara eksplisit.
#
# Mencoba membagi 'limapuluh' dengan '10'...
#   -> ERROR Konversi: Input tidak valid.
#      Detail Error (ValueError): could not convert string to float: 'limapuluh'
#
# Mencoba membagi '10' dengan '[]'...
#   -> ERROR Lainnya: Terjadi kesalahan tak terduga.
#      Detail Error (Lainnya): TypeError - float() argument must be a string or a real number, not 'list'
#
# --- Ringkasan Hasil ---
# Hasil 1 (100/5): 20.0
# Hasil 2 (20/0): None
# Hasil 3 ('limapuluh'/10): None
# Hasil 4 (10/[]): None

# %% [markdown]
# # Praktikum 05: Membangkitkan Exception (raise) dalam Metode

# %%
import locale

# --- Pengaturan Locale & Helper ---
try:
    locale.setlocale(locale.LC_ALL, 'id_ID.UTF-8')
except locale.Error:
    print("... Info: Locale id_ID tidak tersedia di sistem ini, beralih ke format cadangan.\n")

def format_rupiah(angka):
    try:
        return locale.currency(angka, grouping=True, symbol='Rp ')
    except (NameError, ValueError, locale.Error):
        # Cadangan jika sistem tidak mendukung locale Indonesia (mencegah error 'C' locale)
        return f"Rp {angka:,.2f}"


# --- Kelas Logika Bisnis ---
class PengelolaAkun:
    def __init__(self, nomor_akun, saldo_awal=0):
        print(f"Mencoba membuat akun {nomor_akun}...")
        if not isinstance(saldo_awal, (int, float)) or saldo_awal < 0:
            # 1. Raise ValueError di __init__ jika saldo awal tidak valid
            raise ValueError(f"Saldo awal ({saldo_awal}) tidak valid. Harus angka non-negatif.")

        self.nomor_akun = nomor_akun
        self._saldo = float(saldo_awal)
        print(f"  -> Akun {self.nomor_akun} berhasil dibuat dengan saldo: {format_rupiah(self._saldo)}")

    def get_saldo(self):
        """Mengembalikan saldo saat ini."""
        return self._saldo

    def tarik_tunai(self, jumlah):
        """Penarikan tunai dengan validasi. Me-raise exception jika gagal."""
        print(f"\n[{self.nomor_akun}] Mencoba tarik tunai: {format_rupiah(jumlah)}")

        # 2. Validasi jumlah penarikan
        if not isinstance(jumlah, (int, float)) or jumlah <= 0:
            # Raise ValueError jika jumlah tidak valid
            raise ValueError(f"Jumlah penarikan ({jumlah}) tidak valid. Harus angka positif.")

        # 3. Validasi saldo cukup
        if jumlah > self._saldo:
            # Raise RuntimeError jika saldo tidak cukup
            raise RuntimeError(f"Saldo tidak mencukupi! Saldo: {format_rupiah(self._saldo)}, Diminta: {format_rupiah(jumlah)}")

        # Jika semua validasi lolos, lakukan penarikan
        self._saldo -= jumlah
        print(f"  -> Penarikan {format_rupiah(jumlah)} berhasil.")
        print(f"  -> Saldo sekarang: {format_rupiah(self._saldo)}")
        return True


# --- Kode Utama (Eksekusi Skenario) ---
if __name__ == "__main__":

    # =========================================================================
    # Skenario 1: Gagal membuat akun karena saldo awal tidak valid
    # =========================================================================
    print("--- Skenario 1: Saldo Awal Tidak Valid ---")
    try:
        akun_gagal = PengelolaAkun("ACC001", -50000)
    except ValueError as e:
        print(f"  ERROR DITANGKAP saat pembuatan akun: {e}")

    # =========================================================================
    # Skenario 2: Membuat akun valid, lalu coba transaksi rawan error
    # =========================================================================
    print("\n--- Skenario 2: Akun Valid dan Transaksi ---")

    # Kita buat akunnya di blok tersendiri agar variabel 'akun_sukses' aman tercipta
    try:
        akun_sukses = PengelolaAkun("ACC002", 100000)
    except ValueError as e:
        print(f"  Gagal menginisialisasi akun sukses: {e}")
        akun_sukses = None

    # Transaksi dilakukan hanya jika objek akun_sukses berhasil dibuat
    if akun_sukses is not None:
        try:
            # Transaksi 1: Sukses
            akun_sukses.tarik_tunai(30000)

            # Transaksi 2: Gagal karena jumlah tidak valid (Memicu ValueError)
            print("\n  Mencoba tarik jumlah negatif...")
            akun_sukses.tarik_tunai(-10000)

        except ValueError as e:
            print(f"  ERROR DITANGKAP (ValueError): {e}")
        except RuntimeError as e:
            print(f"  ERROR DITANGKAP (RuntimeError): {e}")

    # =========================================================================
    # Skenario 3: Melanjutkan akun valid, gagal karena saldo tidak cukup
    # =========================================================================
    print("\n--- Skenario 3: Saldo Tidak Cukup ---")

    if akun_sukses is not None:
        try:
            print(f"  Saldo akun ACC002 saat ini: {format_rupiah(akun_sukses.get_saldo())}")
            print("  Mencoba tarik jumlah > saldo...")
            akun_sukses.tarik_tunai(80000)  # Saldo hanya sisa 70000

        except ValueError as e:
            print(f"  ERROR DITANGKAP (ValueError): {e}")
        except RuntimeError as e:
            print(f"  ERROR DITANGKAP (RuntimeError): {e}")  # Ini yang diharapkan tertangkap

        print(f"\nSaldo akhir akun ACC002: {format_rupiah(akun_sukses.get_saldo())}")
    else:
        print("  Skenario 3 diabaikan karena objek akun_sukses tidak tersedia.")
# Out:
# ... Info: Locale id_ID tidak tersedia di sistem ini, beralih ke format cadangan.
#
# --- Skenario 1: Saldo Awal Tidak Valid ---
# Mencoba membuat akun ACC001...
#   ERROR DITANGKAP saat pembuatan akun: Saldo awal (-50000) tidak valid. Harus angka non-negatif.
#
# --- Skenario 2: Akun Valid dan Transaksi ---
# Mencoba membuat akun ACC002...
#   -> Akun ACC002 berhasil dibuat dengan saldo: Rp 100,000.00
#
# [ACC002] Mencoba tarik tunai: Rp 30,000.00
#   -> Penarikan Rp 30,000.00 berhasil.
#   -> Saldo sekarang: Rp 70,000.00
#
#   Mencoba tarik jumlah negatif...
#
# [ACC002] Mencoba tarik tunai: Rp -10,000.00
#   ERROR DITANGKAP (ValueError): Jumlah penarikan (-10000) tidak valid. Harus angka positif.
#
# --- Skenario 3: Saldo Tidak Cukup ---
#   Saldo akun ACC002 saat ini: Rp 70,000.00
#   Mencoba tarik jumlah > saldo...
#
# [ACC002] Mencoba tarik tunai: Rp 80,000.00
#   ERROR DITANGKAP (RuntimeError): Saldo tidak mencukupi! Saldo: Rp 70,000.00, Diminta: Rp 80,000.00
#
# Saldo akhir akun ACC002: Rp 70,000.00

# %% [markdown]
# # Praktikum 06: Kombinasi Menangkap dan Membangkitkan Exception

# %%
# 1. Definisikan Custom Exception (mewarisi dari Exception)
class KonfigurasiError(Exception):
    """Exception khusus untuk menandakan error terkait konfigurasi aplikasi."""
    def __init__(self, message, penyebab_asli=None):
        super().__init__(message)
        self.penyebab_asli = penyebab_asli  # Menyimpan error asli jika ada

    def __str__(self):
        if self.penyebab_asli:
            return f"{super().__str__()} (Disebabkan oleh: {type(self.penyebab_asli).__name__})"
        return super().__str__()


# 2. Kelas yang menggunakan exception handling gabungan
class PengelolaSetting:
    def __init__(self, file_config):
        self._config = {}
        self.file_config = file_config

        # Panggil metode internal yang berpotensi raise KonfigurasiError
        try:
            self._load_config()
            print(f"-> PengelolaSetting berhasil dibuat untuk '{self.file_config}'.")
        except KonfigurasiError as e:
            print(f"-> GAGAL membuat PengelolaSetting: {e}")
            # Mengeset state default agar aplikasi tidak crash dan tetap punya data backup
            self._config = {"host": "localhost", "port": 80}
            print("   -> Menggunakan konfigurasi default/fallback (localhost:80).")

    def _load_config(self):
        """Metode internal untuk load config. Bisa raise KonfigurasiError."""
        print(f"\n  [{self.file_config}] Mencoba load konfigurasi...")
        try:
            # --- Potensi FileNotFoundError ---
            print(f"    Membuka file '{self.file_config}'...")
            # Simulasi: anggap hanya file 'config.txt' yang valid untuk dibaca
            if self.file_config != 'config.txt':
                raise FileNotFoundError(f"File '{self.file_config}' tidak ada.")

            # --- Potensi Error Isi File (KeyError, ValueError) ---
            print(f"    Membaca dan validasi isi '{self.file_config}'...")

            # Dinamisasi simulasi berdasarkan parameter nama file/skenario (agar skenario 3 bisa sukses)
            if self.file_config == 'config.txt' and getattr(self, '_simulasi_sukses', False):
                data_raw = {"host": "192.168.1.1", "port": "8080"}  # Port benar (Skenario 3)
            else:
                data_raw = {"host": "192.168.1.1", "port": "xyz"}   # Port salah tipe (Skenario 2)

            # Cek key 'port'
            port_str = data_raw['port']  # Bisa raise KeyError

            # Cek tipe 'port'
            port_int = int(port_str)     # Bisa raise ValueError

            # Jika lolos, simpan
            self._config['port'] = port_int
            self._config['host'] = data_raw.get('host', 'localhost')
            print("    -> Konfigurasi berhasil di-load dan divalidasi.")

        # --- Blok Except & Re-raising Exception ---
        except FileNotFoundError as e_fnf:
            print(f"    ERROR Bawaan: File tidak ditemukan.")
            raise KonfigurasiError(f"File konfigurasi penting '{self.file_config}' hilang.", penyebab_asli=e_fnf) from e_fnf

        except KeyError as e_key:
            print(f"    ERROR Bawaan: Kunci konfigurasi hilang.")
            raise KonfigurasiError(f"Kunci '{e_key}' wajib ada dalam file konfigurasi.", penyebab_asli=e_key) from e_key

        except ValueError as e_val:
            print(f"    ERROR Bawaan: Nilai konfigurasi tidak valid.")
            raise KonfigurasiError(f"Nilai untuk 'port' ('{port_str}') harus integer.", penyebab_asli=e_val) from e_val

        except Exception as e_lain:
            print(f"    ERROR Bawaan Tak Terduga: {type(e_lain).__name__}")
            raise KonfigurasiError(f"Terjadi error tak terduga saat memuat konfigurasi.", penyebab_asli=e_lain) from e_lain

    def get_setting(self, key, default=None):
        """Mendapatkan nilai setting."""
        return self._config.get(key, default)


# --- Kode Utama ---
if __name__ == "__main__":
    # Skenario 1: File tidak ada -> Menghasilkan KonfigurasiError (FileNotFoundError)
    print("--- Skenario 1: File Salah ---")
    settings1 = PengelolaSetting("setting.cfg")
# Out:
# --- Skenario 1: File Salah ---
#
#   [setting.cfg] Mencoba load konfigurasi...
#     Membuka file 'setting.cfg'...
#     ERROR Bawaan: File tidak ditemukan.
# -> GAGAL membuat PengelolaSetting: File konfigurasi penting 'setting.cfg' hilang. (Disebabkan oleh: FileNotFoundError)
#    -> Menggunakan konfigurasi default/fallback (localhost:80).

# %% [markdown]
# # Penugasan 1 - Buat Program dan Kelas diagram untuk membuat kelas InventarisBarang yang mengelola stok barang dan menerapkan exception handling untuk operasi-operasinya.

# %%
"""
======================================================
  Program: Manajemen Inventaris Barang
  Deskripsi: Kelas InventarisBarang dengan exception
             handling untuk operasi stok barang.
======================================================
"""


class InventarisBarang:
    """
    Kelas untuk mengelola inventaris barang toko.
    Data stok disimpan dalam dictionary private _items
    dengan format: { kode_barang (str) : jumlah_stok (int) }
    """

    def __init__(self):
        """
        Konstruktor: menginisialisasi dictionary kosong sebagai
        atribut protected _items untuk menyimpan data stok barang.
        """
        self._items = {}
        print(" Sistem Inventaris Barang berhasil diinisialisasi.\n")

    # ------------------------------------------------------------------
    # METHOD: tambah_barang
    # ------------------------------------------------------------------
    def tambah_barang(self, kode, jumlah):
        """
        Menambahkan barang BARU ke dalam inventaris.

        Catatan penting:
        - Metode ini HANYA untuk barang baru (kode belum ada).
        - Jika kode sudah ada, akan di-raise KeyError ke pemanggil.
        - Jika jumlah bukan integer positif, ValueError ditangkap di sini.

        Parameter:
            kode   (str) : kode unik barang
            jumlah (any) : jumlah stok awal (harus integer positif)
        """
        # --- Validasi tipe & nilai jumlah ---
        # int(jumlah) akan raise ValueError jika jumlah bukan angka.
        # Kita juga memeriksa apakah jumlah > 0 (stok tidak boleh nol/negatif).
        try:
            jumlah = int(jumlah)
            if jumlah <= 0:
                raise ValueError  # Picu penanganan error di bawah
        except ValueError:
            print(f"  [ERROR] tambah_barang: Jumlah '{jumlah}' tidak valid. "
                  f"Harus berupa bilangan bulat positif.\n")
            return  # Hentikan eksekusi metode

        # --- Periksa apakah kode sudah ada ---
        # Jika sudah ada, raise KeyError agar bisa ditangkap di kode utama.
        if kode in self._items:
            raise KeyError(f"Kode barang '{kode}' sudah ada di inventaris.")

        # --- Tambahkan barang baru ---
        self._items[kode] = jumlah
        print(f"  [OK] Barang '{kode}' berhasil ditambahkan dengan stok {jumlah} unit.\n")

    # ------------------------------------------------------------------
    # METHOD: ambil_barang
    # ------------------------------------------------------------------
    def ambil_barang(self, kode, jumlah):
        """
        Mengambil (mengurangi) stok barang dari inventaris.

        Catatan penting:
        - ValueError untuk jumlah tidak valid ditangkap di dalam metode.
        - KeyError (kode tidak ada) ditangkap di dalam metode.
        - Jika stok tidak mencukupi, ValueError di-raise ke pemanggil.

        Parameter:
            kode   (str) : kode barang yang akan diambil
            jumlah (any) : jumlah yang ingin diambil (harus integer positif)
        """
        # --- Validasi tipe & nilai jumlah ---
        try:
            jumlah = int(jumlah)
            if jumlah <= 0:
                raise ValueError
        except ValueError:
            print(f"  [ERROR] ambil_barang: Jumlah '{jumlah}' tidak valid. "
                  f"Harus berupa bilangan bulat positif.\n")
            return

        # --- Periksa apakah kode barang tersedia ---
        # KeyError ditangkap langsung di sini dan tidak di-propagate ke pemanggil.
        try:
            stok_sekarang = self._items[kode]  # Akan raise KeyError jika tidak ada
        except KeyError:
            print(f"  [ERROR] ambil_barang: Kode barang '{kode}' tidak ditemukan "
                  f"di inventaris.\n")
            return

        # --- Periksa kecukupan stok ---
        # Jika stok kurang dari yang diminta, raise ValueError ke kode utama.
        if jumlah > stok_sekarang:
            raise ValueError(
                f"Stok barang '{kode}' tidak mencukupi "
                f"(tersedia: {stok_sekarang}, diminta: {jumlah})."
            )

        # --- Kurangi stok ---
        self._items[kode] -= jumlah
        print(f"  [OK] Berhasil mengambil {jumlah} unit '{kode}'. "
              f"Sisa stok: {self._items[kode]} unit.\n")

    # ------------------------------------------------------------------
    # METHOD: cek_stok
    # ------------------------------------------------------------------
    def cek_stok(self, kode):
        """
        Memeriksa dan menampilkan jumlah stok untuk kode barang tertentu.

        Catatan penting:
        - Menggunakan pola try...except...else...finally:
            * try     : mencoba mengakses stok
            * except  : menangkap KeyError jika kode tidak ada
            * else    : dijalankan HANYA jika try berhasil (tidak ada error)
            * finally : SELALU dijalankan, apapun hasilnya

        Parameter:
            kode (str) : kode barang yang ingin dicek
        """
        print(f"  [INFO] Mengecek stok untuk kode: '{kode}'...")
        try:
            stok = self._items[kode]  # Akan raise KeyError jika tidak ada
        except KeyError:
            print(f"  [ERROR] cek_stok: Kode barang '{kode}' tidak ditemukan.")
        else:
            # Blok ini HANYA berjalan jika try sukses (tidak ada exception)
            print(f"  [OK] Stok barang '{kode}': {stok} unit.")
        finally:
            # Blok ini SELALU berjalan, baik ada exception maupun tidak
            print(f"  [INFO] Pengecekan stok untuk '{kode}' selesai.\n")


# ======================================================================
# KODE UTAMA
# ======================================================================
if __name__ == "__main__":

    print("=" * 60)
    print("       SIMULASI SISTEM INVENTARIS BARANG")
    print("=" * 60 + "\n")

    # Buat instance inventaris
    inv = InventarisBarang()

    # ------------------------------------------------------------------
    # SKENARIO 1: Menambahkan Barang
    # ------------------------------------------------------------------
    print("--- [SKENARIO 1] Menambahkan Barang ---\n")

    # 1a. Tambah barang baru - sukses
    try:
        inv.tambah_barang("BRG001", 50)
        inv.tambah_barang("BRG002", 30)
        inv.tambah_barang("BRG003", 100)
    except KeyError as e:
        print(f"  [TANGKAP KeyError] {e}\n")

    # 1b. Coba tambah kode yang sudah ada - akan raise KeyError
    print("  > Mencoba tambah kode 'BRG001' yang sudah ada:")
    try:
        inv.tambah_barang("BRG001", 20)
    except KeyError as e:
        print(f"  [TANGKAP KeyError] {e}\n")

    # 1c. Coba tambah dengan jumlah tidak valid (string)
    print("  > Mencoba tambah dengan jumlah tidak valid ('abc'):")
    inv.tambah_barang("BRG004", "abc")  # Error ditangkap di dalam metode

    # 1d. Coba tambah dengan jumlah negatif
    print("  > Mencoba tambah dengan jumlah negatif (-5):")
    inv.tambah_barang("BRG005", -5)  # Error ditangkap di dalam metode

    # ------------------------------------------------------------------
    # SKENARIO 2: Mengambil Barang
    # ------------------------------------------------------------------
    print("--- [SKENARIO 2] Mengambil Barang ---\n")

    # 2a. Pengambilan sukses
    print("  > Ambil 10 unit BRG001 (stok: 50):")
    try:
        inv.ambil_barang("BRG001", 10)
    except ValueError as e:
        print(f"  [TANGKAP ValueError] {e}\n")

    # 2b. Kode barang tidak ada - KeyError ditangkap di dalam metode
    print("  > Ambil barang dengan kode tidak ada ('BRG999'):")
    inv.ambil_barang("BRG999", 5)  # Error ditangkap di dalam metode

    # 2c. Jumlah tidak valid - ValueError ditangkap di dalam metode
    print("  > Ambil dengan jumlah tidak valid (0):")
    inv.ambil_barang("BRG001", 0)  # Error ditangkap di dalam metode

    # 2d. Stok tidak mencukupi - ValueError di-raise ke kode utama
    print("  > Ambil 999 unit BRG002 (stok hanya 30):")
    try:
        inv.ambil_barang("BRG002", 999)
    except ValueError as e:
        print(f"  [TANGKAP ValueError] {e}\n")

    # ------------------------------------------------------------------
    # SKENARIO 3: Cek Stok
    # ------------------------------------------------------------------
    print("--- [SKENARIO 3] Cek Stok ---\n")

    # 3a. Kode ada - akan masuk blok else
    inv.cek_stok("BRG001")

    # 3b. Kode ada
    inv.cek_stok("BRG003")

    # 3c. Kode tidak ada - akan masuk blok except, bukan else
    inv.cek_stok("BRG999")

    # ------------------------------------------------------------------
    print("=" * 60)
    print("       SIMULASI SELESAI")
    print("=" * 60)
# Out:
# ============================================================
#        SIMULASI SISTEM INVENTARIS BARANG
# ============================================================
#
#  Sistem Inventaris Barang berhasil diinisialisasi.
#
# --- [SKENARIO 1] Menambahkan Barang ---
#
#   [OK] Barang 'BRG001' berhasil ditambahkan dengan stok 50 unit.
#
#   [OK] Barang 'BRG002' berhasil ditambahkan dengan stok 30 unit.
#
#   [OK] Barang 'BRG003' berhasil ditambahkan dengan stok 100 unit.
#
#   > Mencoba tambah kode 'BRG001' yang sudah ada:
#   [TANGKAP KeyError] "Kode barang 'BRG001' sudah ada di inventaris."
#
#   > Mencoba tambah dengan jumlah tidak valid ('abc'):
#   [ERROR] tambah_barang: Jumlah 'abc' tidak valid. Harus berupa bilangan bulat positif.
#
#   > Mencoba tambah dengan jumlah negatif (-5):
#   [ERROR] tambah_barang: Jumlah '-5' tidak valid. Harus berupa bilangan bulat positif.
#
# --- [SKENARIO 2] Mengambil Barang ---
#
#   > Ambil 10 unit BRG001 (stok: 50):
#   [OK] Berhasil mengambil 10 unit 'BRG001'. Sisa stok: 40 unit.
#
#   > Ambil barang dengan kode tidak ada ('BRG999'):
#   [ERROR] ambil_barang: Kode barang 'BRG999' tidak ditemukan di inventaris.
#
#   > Ambil dengan jumlah tidak valid (0):
#   [ERROR] ambil_barang: Jumlah '0' tidak valid. Harus berupa bilangan bulat positif.
#
#   > Ambil 999 unit BRG002 (stok hanya 30):
#   [TANGKAP ValueError] Stok barang 'BRG002' tidak mencukupi (tersedia: 30, diminta: 999).
#
# --- [SKENARIO 3] Cek Stok ---
#
#   [INFO] Mengecek stok untuk kode: 'BRG001'...
#   [OK] Stok barang 'BRG001': 40 unit.
#   [INFO] Pengecekan stok untuk 'BRG001' selesai.
#
#   [INFO] Mengecek stok untuk kode: 'BRG003'...
#   [OK] Stok barang 'BRG003': 100 unit.
#   [INFO] Pengecekan stok untuk 'BRG003' selesai.
#
#   [INFO] Mengecek stok untuk kode: 'BRG999'...
#   [ERROR] cek_stok: Kode barang 'BRG999' tidak ditemukan.
#   [INFO] Pengecekan stok untuk 'BRG999' selesai.
#
# ============================================================
#        SIMULASI SELESAI
# ============================================================

# %% [markdown]
# ![image.png](data:image/png;base64,...)
